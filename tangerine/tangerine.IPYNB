# %%
import pandas as pd
import os
import glob
import joblib
from notion_client import Client
from notion_client.helpers import is_full_page
import config
from influxdb_client import InfluxDBClient, Point, WritePrecision
from influxdb_client.client.write_api import SYNCHRONOUS, ASYNCHRONOUS
import argparse
import datetime
from datetime import tzinfo



config_file = 'config.ini'

path = 'transactions/sept28_2024/'


cfg = config.Config(config_file)

# %%
all_files = glob.glob(os.path.join(path, "*.csv"))

df = pd.concat((pd.read_csv(f) for f in all_files), ignore_index=True)

df['Date'] = df['Transaction date'].combine_first(df['Date'])
df.pop('Transaction date')
df['Date'] = pd.to_datetime(df['Date'], format='%m/%d/%Y')


df['hash'] = df.apply(joblib.hash, axis=1)
df
# Out:
#    Transaction                              Name  \
# 0        DEBIT  SQ *SEALY KARATE SCHOO Guelph ON
# 1        DEBIT  TERRY FOX* COLE LMENTA BURNABY B
# 2        DEBIT     ZEHRS #38 - ERAMOSA GUELPH ON
# 3        DEBIT     MCDONALD'S #18461 WATERLOO ON
# 4        DEBIT           FRESHCO #3847 GUELPH ON
# 5        DEBIT       PUR SIMPLE GUELPH GUELPH ON
# 6        DEBIT           SQ *HC APPLEZ Guelph ON
# 7        DEBIT           SQ *HC APPLEZ Guelph ON
# 8        DEBIT  7-ELEVEN #29092 (BULLO GUELPH ON
# 9        DEBIT  BLUEBIRD CAFE & GRILL ORANGEVILL
# 10       DEBIT        SQ *HELLOSKYWALKER Mono ON
# 11       DEBIT         SQ *ORBIT STUDIOS Mono ON
# 12       DEBIT       MCDONALD'S #40830 GUELPH ON
# 13       DEBIT       MCDONALD'S #40830 GUELPH ON
# 14       DEBIT  SCHOLASTIC BOOK FAIRS BRAMPTON O
# 15       DEBIT  PAYPAL *PMALL COM 4029357733 IL
# 16       DEBIT  PAYPAL *CUSTOMMEANI 8564196413 T
# 17       DEBIT       TIM HORTONS #1542 GUELPH ON
# 18       DEBIT            JAMSCHOOL NW GUELPH ON
# 19       DEBIT  ROGERS ******1606 888-764-3771 O
# 20       DEBIT     MCDONALD'S #18461 WATERLOO ON
# 21       DEBIT       PIZZA PIZZA # 610 GUELPH ON
# 22       DEBIT  TERANET POA HANDLING F TORONTO O
# 23       DEBIT         CITY OF OTTAWA TORONTO ON
# 24       DEBIT       TIM HORTONS #0508 GUELPH ON
# 25       DEBIT       MCDONALD'S #40830 GUELPH ON
# 26       DEBIT  Amazon.ca*8L15651P3 AMAZON.CA ON
# 27       DEBIT  Amazon.ca*D73VK06H3 AMAZON.CA ON
# 28       DEBIT   Plaid Inc. San Francisco CA USA
# 29       DEBIT           FRESHCO #3847 GUELPH ON
# 30       DEBIT         FOOD BASICS 678 GUELPH ON
# 31       DEBIT      CANADIAN TIRE #260 GUELPH ON
# 32       DEBIT      CANADIAN TIRE #260 GUELPH ON
# 33       DEBIT    SBUX 84619 ZEHRS 538 GUELPH ON
# 34       DEBIT     SP BOOST YOUR LUNCH GUELPH ON
# 35       DEBIT     ZEHRS #38 - ERAMOSA GUELPH ON
# 36       OTHER  INTERAC e-Transfer From: MIEBET
# 37       OTHER    EFT Withdrawal to GUELPH HYDRO
# 38       OTHER  Interac - Purchase - DOLLARAMA #
# 39       OTHER  INTERAC e-Transfer To: Chantalle
# 40       OTHER  INTERAC e-Transfer From: LYRINDA
# 41       OTHER    EFT Withdrawal to Enbridge Gas
# 42       OTHER           EFT Deposit from CANADA
# 43       OTHER  INTERAC e-Transfer To: Rebecca S
# 44       OTHER  EFT Deposit from COGNITIVE SYSTE
# 45       OTHER  INTERAC e-Transfer From: Cecilia
# 46       OTHER  EFT Withdrawal to 2600459RBC PYT
# 47       OTHER  EFT Withdrawal to CITY OF GUELPH
#
#                                                  Memo   Amount       Date  \
# 0              Rewards earned: 0.79 ~ Category: Other  -158.20 2024-09-26
# 1              Rewards earned: 0.13 ~ Category: Other   -25.00 2024-09-26
# 2          Rewards earned: 0.51 ~ Category: Groceries   -25.59 2024-09-25
# 3         Rewards earned: 0.16 ~ Category: Restaurant    -7.90 2024-09-25
# 4          Rewards earned: 4.01 ~ Category: Groceries  -200.47 2024-09-23
# 5         Rewards earned: 0.57 ~ Category: Restaurant   -28.27 2024-09-23
# 6              Rewards earned: 0.07 ~ Category: Other   -14.00 2024-09-22
# 7              Rewards earned: 0.09 ~ Category: Other   -18.00 2024-09-22
# 8                Rewards earned: 0.21 ~ Category: Gas   -41.44 2024-09-21
# 9         Rewards earned: 0.97 ~ Category: Restaurant   -48.44 2024-09-21
# 10     Rewards earned: 0.10 ~ Category: Entertainment   -20.00 2024-09-21
# 11             Rewards earned: 0.08 ~ Category: Other   -15.00 2024-09-21
# 12        Rewards earned: 0.23 ~ Category: Restaurant   -11.73 2024-09-20
# 13        Rewards earned: 0.20 ~ Category: Restaurant    -9.82 2024-09-20
# 14             Rewards earned: 0.24 ~ Category: Other   -47.00 2024-09-19
# 15      Rewards earned: 0.74 ~ Category: Bill Payment   -36.84 2024-09-18
# 16             Rewards earned: 0.12 ~ Category: Other   -23.05 2024-09-18
# 17        Rewards earned: 0.15 ~ Category: Restaurant    -7.32 2024-09-18
# 18             Rewards earned: 0.07 ~ Category: Other   -13.64 2024-09-18
# 19      Rewards earned: 1.58 ~ Category: Bill Payment   -79.09 2024-09-17
# 20        Rewards earned: 0.16 ~ Category: Restaurant    -7.90 2024-09-17
# 21        Rewards earned: 0.39 ~ Category: Restaurant   -19.52 2024-09-17
# 22             Rewards earned: 0.01 ~ Category: Other    -1.66 2024-09-16
# 23             Rewards earned: 0.48 ~ Category: Other   -95.00 2024-09-16
# 24        Rewards earned: 0.24 ~ Category: Restaurant   -11.96 2024-09-16
# 25        Rewards earned: 0.19 ~ Category: Restaurant    -9.47 2024-09-15
# 26             Rewards earned: 0.90 ~ Category: Other  -180.79 2024-09-15
# 27             Rewards earned: 0.14 ~ Category: Other   -27.29 2024-09-15
# 28      Rewards earned: 0.06 ~ Category: Bill Payment    -3.20 2024-09-15
# 29         Rewards earned: 3.47 ~ Category: Groceries  -173.25 2024-09-14
# 30         Rewards earned: 0.47 ~ Category: Groceries   -23.60 2024-09-14
# 31  Rewards earned: 0.12 ~ Category: Home Improvement   -23.72 2024-09-14
# 32  Rewards earned: 0.39 ~ Category: Home Improvement   -78.76 2024-09-14
# 33        Rewards earned: 0.28 ~ Category: Restaurant   -14.13 2024-09-13
# 34        Rewards earned: 1.32 ~ Category: Restaurant   -66.00 2024-09-13
# 35         Rewards earned: 0.95 ~ Category: Groceries   -47.40 2024-09-13
# 36                                        Transferred    55.00 2024-09-14
# 37                                    To GUELPH HYDRO  -307.08 2024-09-16
# 38                     DOLLARAMA # 712 GUELPH  ON  CA    -4.21 2024-09-16
# 39                                        Transferred  -135.00 2024-09-17
# 40                                        Transferred   112.00 2024-09-18
# 41                                    To Enbridge Gas   -43.12 2024-09-18
# 42                                        From CANADA   254.33 2024-09-19
# 43                                        Transferred  -205.00 2024-09-19
# 44                               From COGNITIVE SYSTE  5748.91 2024-09-19
# 45                                        Transferred   120.00 2024-09-22
# 46                                  To 2600459RBC PYT  -556.70 2024-09-27
# 47                                 To CITY OF GUELPH-  -426.13 2024-09-27
#
#                                 hash
# 0   b0474e5415ee1321e19a8874b5edb85d
# 1   e35c38584d66e2327cc0d6ea84a30166
# 2   1175cfadac37048cb86a9d545d93e6e2
# 3   81a0e02e182dcb076643c45af21cb03d
# 4   116f0bf12aeb6ae207ce89f7f5ca78b0
# 5   4bb12ed61772446d60ac36539e98531d
# 6   db61391d399751612b10f9eb3bd708f7
# 7   9657a0d4bbb52346f1171b61c2cdf959
# 8   a44978112cbc90e079e9e64664b2126e
# 9   81e65a64bbbefc6e65f60b00b6999aca
# 10  156b7275db6369cfa6a7797f06f0a832
# 11  c184ad2c781ec823c23114c1723b11e2
# 12  ff5d7df1f2d3f1c6b07d98abb2d7336d
# 13  61c2f8783fd1c179e25cb9bce73ecfa2
# 14  25403528cd38c8b30e042c367fa8a9b4
# 15  53d402b1aba755c5e8c29e18fa338da0
# 16  ae79f54148fec2edfea2efb040389204
# 17  50a6c63c63ff7164a5e4760ebd3e40ce
# 18  411a6d8bd72f43d2680e2e585afc8db4
# 19  8594da23e8b13dc3b9dc791a1532d838
# 20  d859425fa66c89a4b17534057396f78b
# 21  9ba6047ea11afe13c527a070247c53cc
# 22  9b8f5f28ff3803ed2ffb791f48bff78a
# 23  26a449792628635ed88bc8d6fdd1625b
# 24  9ddc57158867e68d35b4c981d4e0c5a7
# 25  52198c08bafb9656ab35dc749fd6597d
# 26  152de4d30a4ec5dfbc317b800e9aee8c
# 27  412e209609cc09fe2674181268b4b502
# 28  b342bc02e28e597ebd7ace793fa85db4
# 29  13361a0bbf04322f0aa282ea7c617d41
# 30  64f89952d56ca642e2c107f220fcdb45
# 31  865c68dace9ecffc7aba8b26fb430f3a
# 32  17b315e0b67d5a8994847588035b28ff
# 33  c0f172877f49863e9f4f88c0425d1c72
# 34  4ea5822034ab5531ff8583b2512ef32c
# 35  7e1299ba58f61bd984947a153b082e63
# 36  3a7d4f0673e72adb9ceb9b4d6a129eef
# 37  9016c1823bc635c7ae4092fe0f758a6d
# 38  a9cb56d5c64078214b7332c9ad0acaad
# 39  a0b8d69a8711358d34591e5379ec080b
# 40  b87a7bbcfbe2f30d52b4dbecf3fca1d8
# 41  aefd2d9abec71f75e0b0b0c96c56e8a5
# 42  b8c98db47fcc36245ad8c3adf7638c52
# 43  cff6a976d3af4774d1109a6f1de2ad34
# 44  c0f52c449ab22c56ae47fa8724aff16f
# 45  b014ab6bccd24e054459958dc8a14098
# 46  ed0fd964613b9f2281eaaeb9ea38fbee
# 47  fe431b0fc43878bf0a780183dbac4e60

# %%
notion_secret = cfg.config['TANGERINE']['notion_secret']
notion_database = cfg.config['TANGERINE']['notion_database']
notion = Client(auth=notion_secret)

full_or_partial_pages = notion.databases.query(database_id=notion_database)
rules = []
for page in full_or_partial_pages["results"]:
    if not is_full_page(page):
        continue
    try:
        #print(page)
        #print(f"Created at: {page['created_time']}")
        if len(page['properties']['Replacement']['multi_select']):
            replacement = page['properties']['Replacement']['multi_select'][0]['name']
        else:
            replacement = None
        method = 'exact'
        key = None
        for t in page['properties']['Type']['multi_select']:
            if t['name'] == 'in':
                method = 'in'
            else:
                key = t['name']
        title = page['properties']['Rule']['title'][0]['text']['content']
        d = dict(replacement=replacement, title=title, method=method, key=key)
        rules.append(d)
    except Exception as e:
        print(e)
        continue

print('notion rules', rules)
filter_rules = list(filter(lambda d: d['replacement'] is None, rules))
# Out:
# notion rules [{'replacement': 'Water Heater', 'title': 'Reliance', 'method': 'in', 'key': 'merchant_name'}, {'replacement': 'Shops', 'title': 'Discount Stores', 'method': 'exact', 'key': 'category'}, {'replacement': 'Kids Activities', 'title': 'Holly Hughes Dance', 'method': 'in', 'key': 'name'}, {'replacement': None, 'title': 'Internet Deposit from Tangerine Chequing Account', 'method': 'in', 'key': 'name'}, {'replacement': None, 'title': 'Internet Withdrawal to Tangerine Savings Account', 'method': 'in', 'key': 'name'}, {'replacement': 'Hobbies', 'title': 'Georgia Simms', 'method': 'in', 'key': 'name'}, {'replacement': 'Mortgage', 'title': 'RBC PYT', 'method': 'in', 'key': 'name'}, {'replacement': 'Groceries', 'title': 'Goodfood', 'method': 'exact', 'key': 'merchant_name'}, {'replacement': None, 'title': 'PAYMENT - THANK YOU', 'method': 'exact', 'key': 'name'}, {'replacement': None, 'title': 'Payment', 'method': 'exact', 'key': 'merchant_name'}, {'replacement': 'Restaurants', 'title': 'Pizza', 'method': 'in', 'key': 'merchant_name'}, {'replacement': 'Payroll', 'title': 'COGNITIVE', 'method': 'in', 'key': 'name'}, {'replacement': 'Restaurants', 'title': 'Food and Beverage', 'method': 'exact', 'key': 'category'}, {'replacement': 'Children', 'title': "Kids' Store", 'method': 'exact', 'key': 'category'}, {'replacement': 'Children', 'title': 'Toys', 'method': 'exact', 'key': 'category'}, {'replacement': 'Shops', 'title': 'Digital Purchase', 'method': 'exact', 'key': 'category'}, {'replacement': 'Clothing and Accessories', 'title': 'Shoe Store', 'method': 'exact', 'key': 'category'}, {'replacement': 'Shops', 'title': 'Department Stores', 'method': 'exact', 'key': 'category'}, {'replacement': 'Pets', 'title': 'Veterinarians', 'method': 'exact', 'key': 'category'}, {'replacement': 'Restaurants', 'title': 'Fast Food', 'method': 'exact', 'key': 'category'}, {'replacement': 'Groceries', 'title': 'Supermarkets and Groceries', 'method': 'exact', 'key': 'category'}, {'replacement': 'Transportation', 'title': 'Parking', 'method': 'exact', 'key': 'category'}, {'replacement': 'Groceries', 'title': 'Costco', 'method': 'exact', 'key': 'name'}, {'replacement': 'Transportation', 'title': 'Etr-web', 'method': 'exact', 'key': 'merchant_name'}, {'replacement': 'Swimming Pool Maintenance and Services', 'title': 'Hot Tub', 'method': 'in', 'key': 'merchant_name'}, {'replacement': 'Gas Stations', 'title': '7-Eleven', 'method': 'exact', 'key': 'merchant_name'}, {'replacement': 'Books', 'title': 'IndiGo', 'method': 'exact', 'key': 'merchant_name'}, {'replacement': 'Hardware Store', 'title': 'Cdn Tire Store', 'method': 'exact', 'key': 'merchant_name'}, {'replacement': 'Groceries', 'title': 'Metro', 'method': 'exact', 'key': 'merchant_name'}, {'replacement': 'Groceries', 'title': 'METRO', 'method': 'in', 'key': 'name'}, {'replacement': 'Insurance', 'title': 'The Personal', 'method': 'exact', 'key': 'merchant_name'}, {'replacement': 'Daycare', 'title': 'Rudolf Steiner', 'method': 'exact', 'key': 'merchant_name'}, {'replacement': 'Investments', 'title': 'Cdn Shr', 'method': 'exact', 'key': 'merchant_name'}, {'replacement': 'Investments', 'title': 'Ws Investments', 'method': 'exact', 'key': 'merchant_name'}, {'replacement': 'Mortgage', 'title': 'Rbc Pyt', 'method': 'exact', 'key': 'merchant_name'}, {'replacement': None, 'title': 'Credit Card Payment', 'method': 'in', 'key': 'name'}, {'replacement': None, 'title': 'PREAUTHORIZED PAYMENT', 'method': 'in', 'key': 'name'}, {'replacement': None, 'title': 'Rogers Bank', 'method': 'in', 'key': 'name'}, {'replacement': None, 'title': 'Internet Deposit from Tangerine Savings Account', 'method': 'in', 'key': 'name'}, {'replacement': None, 'title': 'Internet Withdrawal to Tangerine Chequing Account', 'method': 'in', 'key': 'name'}]

# %%
class Transaction:
    def __init__(self, data, rules=[]):
        self.raw_data = data
        if not data['merchant_name']:
            data['merchant_name'] = data['name']
        old = data['category'][-1]
        for rule in rules:
            if rule['replacement'] is None:
                continue
            if rule['key'] in ['merchant_name', 'name']:
                if rule['method'] == 'exact' and data[rule['key']] == rule['title']:
                    data['category'][-1] = rule['replacement']
                elif rule['method'] == 'in' and rule['title'] in data[rule['key']]:
                    data['category'][-1] = rule['replacement']
            elif rule['key'] == 'category':
                if rule['method'] == 'exact' and data[rule['key']][-1] == rule['title']:
                    data['category'][-1] = rule['replacement']
                elif rule['method'] == 'in' and rule['title'] in data[rule['key']][-1]:
                    data['category'][-1] = rule['replacement']     
                    
        new = data['category'][-1]
        #if old != new:
        #    print(data['name'], old,  new)
        self.account_id     = data['account_id']
        self.date           = data['authorized_date'] if data['authorized_date'] is not None else data['date']
        self.name           = data['name']        
        #print(self.name, data['date'], data['amount'] , data['transaction_id'])
        self.transaction_id = data['transaction_id']
        self.pending        = data['pending']
        self.merchant_name  = data['merchant_name']
        self.amount         = data['amount']
        self.currency_code  = data['iso_currency_code']
        self.category       = data['category']

    def __str__(self):
        return "%s %s %s (%s) - %4.2f %s" % ( self.date, self.transaction_id, self.merchant_name, self.name, self.amount, self.category[-1])
    def __repr__(self):
        return self.__str__()


transactions = []
for _, row in df.iterrows():
    category = row['Memo'].split('Category:')
    if len(category) == 2:
        category = category[-1]
    else:
        category = 'Other'
    t = dict(name=row['Name'], category=[category], date=row['Date'], account_id='NA', transaction_id=row['hash'], pending=False, iso_currency_code='CA', amount=row['Amount'], merchant_name=None, authorized_date=None)
    for rule in filter_rules:
        skip = False
        if rule['method'] == 'exact' and rule['title'] == t[rule['key']]:
            skip = True
            break
        elif rule['method'] == 'in' and rule['title'] in t[rule['key']]:
            skip = True
            break
        if t['pending']:
            skip = True
        if skip:
            continue
    transactions.append(Transaction(t, rules))

# %%
def upload(transactions, cfg, start_date, end_date, verbose=False, dump=False, dry=False):
    old = {}
    client = InfluxDBClient(url=cfg.config['TANGERINE']['influx_url'], token=cfg.config['TANGERINE']['influx_token'],  org=cfg.config['TANGERINE']['influx_org'], timeout=200000)
    try:
        query_api = client.query_api()
        tables = query_api.query('''
        from(bucket: "%s")
          |> range(start: %s, stop: %s)
          |> filter(fn: (r) => r["_measurement"] == "transactions")
          |> group()
          |> sort(columns: ["_time"], desc: false)
        ''' %(cfg.config['TANGERINE']['influx_bucket'], start_date, end_date))
        for table in tables:
            for row in table.records:
                if row['id'] not in old:                    
                    old[row['id']] = row  #could be deleted transaction, track it here
                elif row['_value'] != 0:
                    old[row['id']] = row  # we should only have one transaction with non-zero value
    finally:
        client.close()
    
    lst = []
    for row in old.values():
        if row['_value'] != 0: # only track non-deleted transactions
            lst.append((row['_time'], row['payee'],row['memo'], row['_value'], row['category'], row['id'], row['account']))
    df = pd.DataFrame(lst, columns = ['Date', 'Description', 'Memo', 'Amount', 'Category', 'Check#', 'Account'])
    if verbose:
        print(df)
    if dump:
        df.to_csv('transactions.csv', index=False)
        return    
                  
    client = InfluxDBClient(url=cfg.config['TANGERINE']['influx_url'], token=cfg.config['TANGERINE']['influx_token'], timeout=20000)            
    write_api = client.write_api(write_options=ASYNCHRONOUS)

    tt = transactions
    tt.sort(key=lambda x : x.date)
    for t in tt:
        date = t.date               
        if (date.date() < start_date or date.date() > end_date):
            if verbose:
                print('skipping (out of range)', t)
            continue
        
        skip = True if t.transaction_id in old else False  
        if verbose:
            print('skip', skip, t)

        point = Point("transactions")\
        .tag("payee", t.merchant_name) \
        .tag("memo", t.name) \
        .tag('account', t.account_id) \
        .tag('category', t.category[-1]) \
        .tag('id', t.transaction_id) \
        .field('amount', -1.0 * t.amount)  \
        .time(int(date.timestamp() * 10**9), WritePrecision.NS)
        if not skip:
            if verbose:
                print(point.to_line_protocol(), end='\n~~~~~~~~~~~~~~~~~~~~~~\n')
            if not dry:
                write_api.write(cfg.config['TANGERINE']['influx_bucket'], cfg.config['TANGERINE']['influx_org'], point)
    client.close()

# %%
start_date = df['Date'].min().date()
end_date = df['Date'].max().date()
dry = True
verbose = True
upload(transactions,cfg, start_date, end_date, verbose=verbose, dump=False, dry=dry)
# Out:
#                        Date                       Description  \
# 0 2024-09-13 04:00:00+00:00    Credit Card Rewards Redemption
# 1 2024-09-13 04:00:00+00:00  EFT Withdrawal to 2600616RBC PYT
#
#                                Memo  Amount  Category  \
# 0    Credit Card Rewards Redemption  101.94    Credit
# 1  EFT Withdrawal to 2600616RBC PYT -556.70  Mortgage
#
#                                   Check#     Account
# 0  mQeBnKXXjZiO86PqkLQdC5vr3wQ6KaUm4Oxwa  depository
# 1  MqYLOaDDP0syzYE7LKXJIqZYM7wAeOFBk13nx  depository
# skip False 2024-09-13 00:00:00 c0f172877f49863e9f4f88c0425d1c72 SBUX 84619 ZEHRS 538 GUELPH ON (SBUX 84619 ZEHRS 538 GUELPH ON) - -14.13  Restaurant
# transactions,account=NA,category=\ Restaurant,id=c0f172877f49863e9f4f88c0425d1c72,memo=SBUX\ 84619\ ZEHRS\ 538\ GUELPH\ ON,payee=SBUX\ 84619\ ZEHRS\ 538\ GUELPH\ ON amount=14.13 1726185600000000000
# ~~~~~~~~~~~~~~~~~~~~~~
# skip False 2024-09-13 00:00:00 4ea5822034ab5531ff8583b2512ef32c SP BOOST YOUR LUNCH GUELPH ON (SP BOOST YOUR LUNCH GUELPH ON) - -66.00  Restaurant
# transactions,account=NA,category=\ Restaurant,id=4ea5822034ab5531ff8583b2512ef32c,memo=SP\ BOOST\ YOUR\ LUNCH\ GUELPH\ ON,payee=SP\ BOOST\ YOUR\ LUNCH\ GUELPH\ ON amount=66 1726185600000000000
# ~~~~~~~~~~~~~~~~~~~~~~
# skip False 2024-09-13 00:00:00 7e1299ba58f61bd984947a153b082e63 ZEHRS #38 - ERAMOSA GUELPH ON (ZEHRS #38 - ERAMOSA GUELPH ON) - -47.40  Groceries
# transactions,account=NA,category=\ Groceries,id=7e1299ba58f61bd984947a153b082e63,memo=ZEHRS\ #38\ -\ ERAMOSA\ GUELPH\ ON,payee=ZEHRS\ #38\ -\ ERAMOSA\ GUELPH\ ON amount=47.4 1726185600000000000
# ~~~~~~~~~~~~~~~~~~~~~~
# skip False 2024-09-14 00:00:00 13361a0bbf04322f0aa282ea7c617d41 FRESHCO #3847 GUELPH ON (FRESHCO #3847 GUELPH ON) - -173.25  Groceries
# transactions,account=NA,category=\ Groceries,id=13361a0bbf04322f0aa282ea7c617d41,memo=FRESHCO\ #3847\ GUELPH\ ON,payee=FRESHCO\ #3847\ GUELPH\ ON amount=173.25 1726272000000000000
# ~~~~~~~~~~~~~~~~~~~~~~
# skip False 2024-09-14 00:00:00 64f89952d56ca642e2c107f220fcdb45 FOOD BASICS 678 GUELPH ON (FOOD BASICS 678 GUELPH ON) - -23.60  Groceries
# transactions,account=NA,category=\ Groceries,id=64f89952d56ca642e2c107f220fcdb45,memo=FOOD\ BASICS\ 678\ GUELPH\ ON,payee=FOOD\ BASICS\ 678\ GUELPH\ ON amount=23.6 1726272000000000000
# ~~~~~~~~~~~~~~~~~~~~~~
# skip False 2024-09-14 00:00:00 865c68dace9ecffc7aba8b26fb430f3a CANADIAN TIRE #260 GUELPH ON (CANADIAN TIRE #260 GUELPH ON) - -23.72  Home Improvement
# transactions,account=NA,category=\ Home\ Improvement,id=865c68dace9ecffc7aba8b26fb430f3a,memo=CANADIAN\ TIRE\ #260\ GUELPH\ ON,payee=CANADIAN\ TIRE\ #260\ GUELPH\ ON amount=23.72 1726272000000000000
# ~~~~~~~~~~~~~~~~~~~~~~
# skip False 2024-09-14 00:00:00 17b315e0b67d5a8994847588035b28ff CANADIAN TIRE #260 GUELPH ON (CANADIAN TIRE #260 GUELPH ON) - -78.76  Home Improvement
# transactions,account=NA,category=\ Home\ Improvement,id=17b315e0b67d5a8994847588035b28ff,memo=CANADIAN\ TIRE\ #260\ GUELPH\ ON,payee=CANADIAN\ TIRE\ #260\ GUELPH\ ON amount=78.76 1726272000000000000
# ~~~~~~~~~~~~~~~~~~~~~~
# skip False 2024-09-14 00:00:00 3a7d4f0673e72adb9ceb9b4d6a129eef INTERAC e-Transfer From: MIEBET  (INTERAC e-Transfer From: MIEBET ) - 55.00 Other
# transactions,account=NA,category=Other,id=3a7d4f0673e72adb9ceb9b4d6a129eef,memo=INTERAC\ e-Transfer\ From:\ MIEBET\ ,payee=INTERAC\ e-Transfer\ From:\ MIEBET\  amount=-55 1726272000000000000
# ~~~~~~~~~~~~~~~~~~~~~~
# skip False 2024-09-15 00:00:00 52198c08bafb9656ab35dc749fd6597d MCDONALD'S #40830 GUELPH ON (MCDONALD'S #40830 GUELPH ON) - -9.47  Restaurant
# transactions,account=NA,category=\ Restaurant,id=52198c08bafb9656ab35dc749fd6597d,memo=MCDONALD'S\ #40830\ GUELPH\ ON,payee=MCDONALD'S\ #40830\ GUELPH\ ON amount=9.47 1726358400000000000
# ~~~~~~~~~~~~~~~~~~~~~~
# skip False 2024-09-15 00:00:00 152de4d30a4ec5dfbc317b800e9aee8c Amazon.ca*8L15651P3 AMAZON.CA ON (Amazon.ca*8L15651P3 AMAZON.CA ON) - -180.79  Other
# transactions,account=NA,category=\ Other,id=152de4d30a4ec5dfbc317b800e9aee8c,memo=Amazon.ca*8L15651P3\ AMAZON.CA\ ON,payee=Amazon.ca*8L15651P3\ AMAZON.CA\ ON amount=180.79 1726358400000000000
# ~~~~~~~~~~~~~~~~~~~~~~
# skip False 2024-09-15 00:00:00 412e209609cc09fe2674181268b4b502 Amazon.ca*D73VK06H3 AMAZON.CA ON (Amazon.ca*D73VK06H3 AMAZON.CA ON) - -27.29  Other
# transactions,account=NA,category=\ Other,id=412e209609cc09fe2674181268b4b502,memo=Amazon.ca*D73VK06H3\ AMAZON.CA\ ON,payee=Amazon.ca*D73VK06H3\ AMAZON.CA\ ON amount=27.29 1726358400000000000
# ~~~~~~~~~~~~~~~~~~~~~~
# skip False 2024-09-15 00:00:00 b342bc02e28e597ebd7ace793fa85db4 Plaid Inc. San Francisco CA USA (Plaid Inc. San Francisco CA USA) - -3.20  Bill Payment
# transactions,account=NA,category=\ Bill\ Payment,id=b342bc02e28e597ebd7ace793fa85db4,memo=Plaid\ Inc.\ San\ Francisco\ CA\ USA,payee=Plaid\ Inc.\ San\ Francisco\ CA\ USA amount=3.2 1726358400000000000
# ~~~~~~~~~~~~~~~~~~~~~~
# skip False 2024-09-16 00:00:00 9b8f5f28ff3803ed2ffb791f48bff78a TERANET POA HANDLING F TORONTO O (TERANET POA HANDLING F TORONTO O) - -1.66  Other
# transactions,account=NA,category=\ Other,id=9b8f5f28ff3803ed2ffb791f48bff78a,memo=TERANET\ POA\ HANDLING\ F\ TORONTO\ O,payee=TERANET\ POA\ HANDLING\ F\ TORONTO\ O amount=1.66 1726444800000000000
# ~~~~~~~~~~~~~~~~~~~~~~
# skip False 2024-09-16 00:00:00 26a449792628635ed88bc8d6fdd1625b CITY OF OTTAWA TORONTO ON (CITY OF OTTAWA TORONTO ON) - -95.00  Other
# transactions,account=NA,category=\ Other,id=26a449792628635ed88bc8d6fdd1625b,memo=CITY\ OF\ OTTAWA\ TORONTO\ ON,payee=CITY\ OF\ OTTAWA\ TORONTO\ ON amount=95 1726444800000000000
# ~~~~~~~~~~~~~~~~~~~~~~
# skip False 2024-09-16 00:00:00 9ddc57158867e68d35b4c981d4e0c5a7 TIM HORTONS #0508 GUELPH ON (TIM HORTONS #0508 GUELPH ON) - -11.96  Restaurant
# transactions,account=NA,category=\ Restaurant,id=9ddc57158867e68d35b4c981d4e0c5a7,memo=TIM\ HORTONS\ #0508\ GUELPH\ ON,payee=TIM\ HORTONS\ #0508\ GUELPH\ ON amount=11.96 1726444800000000000
# ~~~~~~~~~~~~~~~~~~~~~~
# skip False 2024-09-16 00:00:00 9016c1823bc635c7ae4092fe0f758a6d EFT Withdrawal to GUELPH HYDRO (EFT Withdrawal to GUELPH HYDRO) - -307.08 Other
# transactions,account=NA,category=Other,id=9016c1823bc635c7ae4092fe0f758a6d,memo=EFT\ Withdrawal\ to\ GUELPH\ HYDRO,payee=EFT\ Withdrawal\ to\ GUELPH\ HYDRO amount=307.08 1726444800000000000
# ~~~~~~~~~~~~~~~~~~~~~~
# skip False 2024-09-16 00:00:00 a9cb56d5c64078214b7332c9ad0acaad Interac - Purchase - DOLLARAMA # (Interac - Purchase - DOLLARAMA #) - -4.21 Other
# transactions,account=NA,category=Other,id=a9cb56d5c64078214b7332c9ad0acaad,memo=Interac\ -\ Purchase\ -\ DOLLARAMA\ #,payee=Interac\ -\ Purchase\ -\ DOLLARAMA\ # amount=4.21 1726444800000000000
# ~~~~~~~~~~~~~~~~~~~~~~
# skip False 2024-09-17 00:00:00 8594da23e8b13dc3b9dc791a1532d838 ROGERS ******1606 888-764-3771 O (ROGERS ******1606 888-764-3771 O) - -79.09  Bill Payment
# transactions,account=NA,category=\ Bill\ Payment,id=8594da23e8b13dc3b9dc791a1532d838,memo=ROGERS\ ******1606\ 888-764-3771\ O,payee=ROGERS\ ******1606\ 888-764-3771\ O amount=79.09 1726531200000000000
# ~~~~~~~~~~~~~~~~~~~~~~
# skip False 2024-09-17 00:00:00 d859425fa66c89a4b17534057396f78b MCDONALD'S #18461 WATERLOO ON (MCDONALD'S #18461 WATERLOO ON) - -7.90  Restaurant
# transactions,account=NA,category=\ Restaurant,id=d859425fa66c89a4b17534057396f78b,memo=MCDONALD'S\ #18461\ WATERLOO\ ON,payee=MCDONALD'S\ #18461\ WATERLOO\ ON amount=7.9 1726531200000000000
# ~~~~~~~~~~~~~~~~~~~~~~
# skip False 2024-09-17 00:00:00 9ba6047ea11afe13c527a070247c53cc PIZZA PIZZA # 610 GUELPH ON (PIZZA PIZZA # 610 GUELPH ON) - -19.52  Restaurant
# transactions,account=NA,category=\ Restaurant,id=9ba6047ea11afe13c527a070247c53cc,memo=PIZZA\ PIZZA\ #\ 610\ GUELPH\ ON,payee=PIZZA\ PIZZA\ #\ 610\ GUELPH\ ON amount=19.52 1726531200000000000
# ~~~~~~~~~~~~~~~~~~~~~~
# skip False 2024-09-17 00:00:00 a0b8d69a8711358d34591e5379ec080b INTERAC e-Transfer To: Chantalle (INTERAC e-Transfer To: Chantalle) - -135.00 Other
# transactions,account=NA,category=Other,id=a0b8d69a8711358d34591e5379ec080b,memo=INTERAC\ e-Transfer\ To:\ Chantalle,payee=INTERAC\ e-Transfer\ To:\ Chantalle amount=135 1726531200000000000
# ~~~~~~~~~~~~~~~~~~~~~~
# skip False 2024-09-18 00:00:00 53d402b1aba755c5e8c29e18fa338da0 PAYPAL *PMALL COM 4029357733 IL  (PAYPAL *PMALL COM 4029357733 IL ) - -36.84  Bill Payment
# transactions,account=NA,category=\ Bill\ Payment,id=53d402b1aba755c5e8c29e18fa338da0,memo=PAYPAL\ *PMALL\ COM\ 4029357733\ IL\ ,payee=PAYPAL\ *PMALL\ COM\ 4029357733\ IL\  amount=36.84 1726617600000000000
# ~~~~~~~~~~~~~~~~~~~~~~
# skip False 2024-09-18 00:00:00 ae79f54148fec2edfea2efb040389204 PAYPAL *CUSTOMMEANI 8564196413 T (PAYPAL *CUSTOMMEANI 8564196413 T) - -23.05  Other
# transactions,account=NA,category=\ Other,id=ae79f54148fec2edfea2efb040389204,memo=PAYPAL\ *CUSTOMMEANI\ 8564196413\ T,payee=PAYPAL\ *CUSTOMMEANI\ 8564196413\ T amount=23.05 1726617600000000000
# ~~~~~~~~~~~~~~~~~~~~~~
# skip False 2024-09-18 00:00:00 50a6c63c63ff7164a5e4760ebd3e40ce TIM HORTONS #1542 GUELPH ON (TIM HORTONS #1542 GUELPH ON) - -7.32  Restaurant
# transactions,account=NA,category=\ Restaurant,id=50a6c63c63ff7164a5e4760ebd3e40ce,memo=TIM\ HORTONS\ #1542\ GUELPH\ ON,payee=TIM\ HORTONS\ #1542\ GUELPH\ ON amount=7.32 1726617600000000000
# ~~~~~~~~~~~~~~~~~~~~~~
# skip False 2024-09-18 00:00:00 411a6d8bd72f43d2680e2e585afc8db4 JAMSCHOOL NW GUELPH ON (JAMSCHOOL NW GUELPH ON) - -13.64  Other
# transactions,account=NA,category=\ Other,id=411a6d8bd72f43d2680e2e585afc8db4,memo=JAMSCHOOL\ NW\ GUELPH\ ON,payee=JAMSCHOOL\ NW\ GUELPH\ ON amount=13.64 1726617600000000000
# ~~~~~~~~~~~~~~~~~~~~~~
# skip False 2024-09-18 00:00:00 b87a7bbcfbe2f30d52b4dbecf3fca1d8 INTERAC e-Transfer From: LYRINDA (INTERAC e-Transfer From: LYRINDA) - 112.00 Other
# transactions,account=NA,category=Other,id=b87a7bbcfbe2f30d52b4dbecf3fca1d8,memo=INTERAC\ e-Transfer\ From:\ LYRINDA,payee=INTERAC\ e-Transfer\ From:\ LYRINDA amount=-112 1726617600000000000
# ~~~~~~~~~~~~~~~~~~~~~~
# skip False 2024-09-18 00:00:00 aefd2d9abec71f75e0b0b0c96c56e8a5 EFT Withdrawal to Enbridge Gas (EFT Withdrawal to Enbridge Gas) - -43.12 Other
# transactions,account=NA,category=Other,id=aefd2d9abec71f75e0b0b0c96c56e8a5,memo=EFT\ Withdrawal\ to\ Enbridge\ Gas,payee=EFT\ Withdrawal\ to\ Enbridge\ Gas amount=43.12 1726617600000000000
# ~~~~~~~~~~~~~~~~~~~~~~
# skip False 2024-09-19 00:00:00 25403528cd38c8b30e042c367fa8a9b4 SCHOLASTIC BOOK FAIRS BRAMPTON O (SCHOLASTIC BOOK FAIRS BRAMPTON O) - -47.00  Other
# transactions,account=NA,category=\ Other,id=25403528cd38c8b30e042c367fa8a9b4,memo=SCHOLASTIC\ BOOK\ FAIRS\ BRAMPTON\ O,payee=SCHOLASTIC\ BOOK\ FAIRS\ BRAMPTON\ O amount=47 1726704000000000000
# ~~~~~~~~~~~~~~~~~~~~~~
# skip False 2024-09-19 00:00:00 b8c98db47fcc36245ad8c3adf7638c52 EFT Deposit from CANADA (EFT Deposit from CANADA) - 254.33 Other
# transactions,account=NA,category=Other,id=b8c98db47fcc36245ad8c3adf7638c52,memo=EFT\ Deposit\ from\ CANADA,payee=EFT\ Deposit\ from\ CANADA amount=-254.33 1726704000000000000
# ~~~~~~~~~~~~~~~~~~~~~~
# skip False 2024-09-19 00:00:00 cff6a976d3af4774d1109a6f1de2ad34 INTERAC e-Transfer To: Rebecca S (INTERAC e-Transfer To: Rebecca S) - -205.00 Other
# transactions,account=NA,category=Other,id=cff6a976d3af4774d1109a6f1de2ad34,memo=INTERAC\ e-Transfer\ To:\ Rebecca\ S,payee=INTERAC\ e-Transfer\ To:\ Rebecca\ S amount=205 1726704000000000000
# ~~~~~~~~~~~~~~~~~~~~~~
# skip False 2024-09-19 00:00:00 c0f52c449ab22c56ae47fa8724aff16f EFT Deposit from COGNITIVE SYSTE (EFT Deposit from COGNITIVE SYSTE) - 5748.91 Payroll
# transactions,account=NA,category=Payroll,id=c0f52c449ab22c56ae47fa8724aff16f,memo=EFT\ Deposit\ from\ COGNITIVE\ SYSTE,payee=EFT\ Deposit\ from\ COGNITIVE\ SYSTE amount=-5748.91 1726704000000000000
# ~~~~~~~~~~~~~~~~~~~~~~
# skip False 2024-09-20 00:00:00 ff5d7df1f2d3f1c6b07d98abb2d7336d MCDONALD'S #40830 GUELPH ON (MCDONALD'S #40830 GUELPH ON) - -11.73  Restaurant
# transactions,account=NA,category=\ Restaurant,id=ff5d7df1f2d3f1c6b07d98abb2d7336d,memo=MCDONALD'S\ #40830\ GUELPH\ ON,payee=MCDONALD'S\ #40830\ GUELPH\ ON amount=11.73 1726790400000000000
# ~~~~~~~~~~~~~~~~~~~~~~
# skip False 2024-09-20 00:00:00 61c2f8783fd1c179e25cb9bce73ecfa2 MCDONALD'S #40830 GUELPH ON (MCDONALD'S #40830 GUELPH ON) - -9.82  Restaurant
# transactions,account=NA,category=\ Restaurant,id=61c2f8783fd1c179e25cb9bce73ecfa2,memo=MCDONALD'S\ #40830\ GUELPH\ ON,payee=MCDONALD'S\ #40830\ GUELPH\ ON amount=9.82 1726790400000000000
# ~~~~~~~~~~~~~~~~~~~~~~
# skip False 2024-09-21 00:00:00 a44978112cbc90e079e9e64664b2126e 7-ELEVEN #29092 (BULLO GUELPH ON (7-ELEVEN #29092 (BULLO GUELPH ON) - -41.44  Gas
# transactions,account=NA,category=\ Gas,id=a44978112cbc90e079e9e64664b2126e,memo=7-ELEVEN\ #29092\ (BULLO\ GUELPH\ ON,payee=7-ELEVEN\ #29092\ (BULLO\ GUELPH\ ON amount=41.44 1726876800000000000
# ~~~~~~~~~~~~~~~~~~~~~~
# skip False 2024-09-21 00:00:00 81e65a64bbbefc6e65f60b00b6999aca BLUEBIRD CAFE & GRILL ORANGEVILL (BLUEBIRD CAFE & GRILL ORANGEVILL) - -48.44  Restaurant
# transactions,account=NA,category=\ Restaurant,id=81e65a64bbbefc6e65f60b00b6999aca,memo=BLUEBIRD\ CAFE\ &\ GRILL\ ORANGEVILL,payee=BLUEBIRD\ CAFE\ &\ GRILL\ ORANGEVILL amount=48.44 1726876800000000000
# ~~~~~~~~~~~~~~~~~~~~~~
# skip False 2024-09-21 00:00:00 156b7275db6369cfa6a7797f06f0a832 SQ *HELLOSKYWALKER Mono ON (SQ *HELLOSKYWALKER Mono ON) - -20.00  Entertainment
# transactions,account=NA,category=\ Entertainment,id=156b7275db6369cfa6a7797f06f0a832,memo=SQ\ *HELLOSKYWALKER\ Mono\ ON,payee=SQ\ *HELLOSKYWALKER\ Mono\ ON amount=20 1726876800000000000
# ~~~~~~~~~~~~~~~~~~~~~~
# skip False 2024-09-21 00:00:00 c184ad2c781ec823c23114c1723b11e2 SQ *ORBIT STUDIOS Mono ON (SQ *ORBIT STUDIOS Mono ON) - -15.00  Other
# transactions,account=NA,category=\ Other,id=c184ad2c781ec823c23114c1723b11e2,memo=SQ\ *ORBIT\ STUDIOS\ Mono\ ON,payee=SQ\ *ORBIT\ STUDIOS\ Mono\ ON amount=15 1726876800000000000
# ~~~~~~~~~~~~~~~~~~~~~~
# skip False 2024-09-22 00:00:00 db61391d399751612b10f9eb3bd708f7 SQ *HC APPLEZ Guelph ON (SQ *HC APPLEZ Guelph ON) - -14.00  Other
# transactions,account=NA,category=\ Other,id=db61391d399751612b10f9eb3bd708f7,memo=SQ\ *HC\ APPLEZ\ Guelph\ ON,payee=SQ\ *HC\ APPLEZ\ Guelph\ ON amount=14 1726963200000000000
# ~~~~~~~~~~~~~~~~~~~~~~
# skip False 2024-09-22 00:00:00 9657a0d4bbb52346f1171b61c2cdf959 SQ *HC APPLEZ Guelph ON (SQ *HC APPLEZ Guelph ON) - -18.00  Other
# transactions,account=NA,category=\ Other,id=9657a0d4bbb52346f1171b61c2cdf959,memo=SQ\ *HC\ APPLEZ\ Guelph\ ON,payee=SQ\ *HC\ APPLEZ\ Guelph\ ON amount=18 1726963200000000000
# ~~~~~~~~~~~~~~~~~~~~~~
# skip False 2024-09-22 00:00:00 b014ab6bccd24e054459958dc8a14098 INTERAC e-Transfer From: Cecilia (INTERAC e-Transfer From: Cecilia) - 120.00 Other
# transactions,account=NA,category=Other,id=b014ab6bccd24e054459958dc8a14098,memo=INTERAC\ e-Transfer\ From:\ Cecilia,payee=INTERAC\ e-Transfer\ From:\ Cecilia amount=-120 1726963200000000000
# ~~~~~~~~~~~~~~~~~~~~~~
# skip False 2024-09-23 00:00:00 116f0bf12aeb6ae207ce89f7f5ca78b0 FRESHCO #3847 GUELPH ON (FRESHCO #3847 GUELPH ON) - -200.47  Groceries
# transactions,account=NA,category=\ Groceries,id=116f0bf12aeb6ae207ce89f7f5ca78b0,memo=FRESHCO\ #3847\ GUELPH\ ON,payee=FRESHCO\ #3847\ GUELPH\ ON amount=200.47 1727049600000000000
# ~~~~~~~~~~~~~~~~~~~~~~
# skip False 2024-09-23 00:00:00 4bb12ed61772446d60ac36539e98531d PUR SIMPLE GUELPH GUELPH ON (PUR SIMPLE GUELPH GUELPH ON) - -28.27  Restaurant
# transactions,account=NA,category=\ Restaurant,id=4bb12ed61772446d60ac36539e98531d,memo=PUR\ SIMPLE\ GUELPH\ GUELPH\ ON,payee=PUR\ SIMPLE\ GUELPH\ GUELPH\ ON amount=28.27 1727049600000000000
# ~~~~~~~~~~~~~~~~~~~~~~
# skip False 2024-09-25 00:00:00 1175cfadac37048cb86a9d545d93e6e2 ZEHRS #38 - ERAMOSA GUELPH ON (ZEHRS #38 - ERAMOSA GUELPH ON) - -25.59  Groceries
# transactions,account=NA,category=\ Groceries,id=1175cfadac37048cb86a9d545d93e6e2,memo=ZEHRS\ #38\ -\ ERAMOSA\ GUELPH\ ON,payee=ZEHRS\ #38\ -\ ERAMOSA\ GUELPH\ ON amount=25.59 1727222400000000000
# ~~~~~~~~~~~~~~~~~~~~~~
# skip False 2024-09-25 00:00:00 81a0e02e182dcb076643c45af21cb03d MCDONALD'S #18461 WATERLOO ON (MCDONALD'S #18461 WATERLOO ON) - -7.90  Restaurant
# transactions,account=NA,category=\ Restaurant,id=81a0e02e182dcb076643c45af21cb03d,memo=MCDONALD'S\ #18461\ WATERLOO\ ON,payee=MCDONALD'S\ #18461\ WATERLOO\ ON amount=7.9 1727222400000000000
# ~~~~~~~~~~~~~~~~~~~~~~
# skip False 2024-09-26 00:00:00 b0474e5415ee1321e19a8874b5edb85d SQ *SEALY KARATE SCHOO Guelph ON (SQ *SEALY KARATE SCHOO Guelph ON) - -158.20  Other
# transactions,account=NA,category=\ Other,id=b0474e5415ee1321e19a8874b5edb85d,memo=SQ\ *SEALY\ KARATE\ SCHOO\ Guelph\ ON,payee=SQ\ *SEALY\ KARATE\ SCHOO\ Guelph\ ON amount=158.2 1727308800000000000
# ~~~~~~~~~~~~~~~~~~~~~~
# skip False 2024-09-26 00:00:00 e35c38584d66e2327cc0d6ea84a30166 TERRY FOX* COLE LMENTA BURNABY B (TERRY FOX* COLE LMENTA BURNABY B) - -25.00  Other
# transactions,account=NA,category=\ Other,id=e35c38584d66e2327cc0d6ea84a30166,memo=TERRY\ FOX*\ COLE\ LMENTA\ BURNABY\ B,payee=TERRY\ FOX*\ COLE\ LMENTA\ BURNABY\ B amount=25 1727308800000000000
# ~~~~~~~~~~~~~~~~~~~~~~
# skip False 2024-09-27 00:00:00 ed0fd964613b9f2281eaaeb9ea38fbee EFT Withdrawal to 2600459RBC PYT (EFT Withdrawal to 2600459RBC PYT) - -556.70 Mortgage
# transactions,account=NA,category=Mortgage,id=ed0fd964613b9f2281eaaeb9ea38fbee,memo=EFT\ Withdrawal\ to\ 2600459RBC\ PYT,payee=EFT\ Withdrawal\ to\ 2600459RBC\ PYT amount=556.7 1727395200000000000
# ~~~~~~~~~~~~~~~~~~~~~~
# skip False 2024-09-27 00:00:00 fe431b0fc43878bf0a780183dbac4e60 EFT Withdrawal to CITY OF GUELPH (EFT Withdrawal to CITY OF GUELPH) - -426.13 Other
# transactions,account=NA,category=Other,id=fe431b0fc43878bf0a780183dbac4e60,memo=EFT\ Withdrawal\ to\ CITY\ OF\ GUELPH,payee=EFT\ Withdrawal\ to\ CITY\ OF\ GUELPH amount=426.13 1727395200000000000
# ~~~~~~~~~~~~~~~~~~~~~~
